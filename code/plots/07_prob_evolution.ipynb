# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import seaborn as sns
import glob

# %%
version = '68'
data = {}
data['UncSampling'] = {}
data['RandomSampling'] = {}

for i in [0,299]:
    fname = '../../../../referee/UncSampling/class_prob/v' + version + \
                  '/class_prob_UncSampling_loop_' + str(i) + '.csv'
    
    data['UncSampling'][i] = pd.read_csv(fname)
    
    fname2 = '../../../../referee/RandomSampling/class_prob/v' + version + \
                  '/class_prob_RandomSampling_loop_' + str(i) + '.csv'
    
    data['RandomSampling'][i] = pd.read_csv(fname2)

# %%
sns.set(rc={'axes.facecolor': 'white', 'figure.facecolor': 'white'})
c = ['#F5622E', '#15284F']

fig = plt.figure(figsize=(8,5))

plt.subplot(1,1,1)
sns.distplot(data['RandomSampling'][0]['prob_Ia'][data['RandomSampling'][0]['type'] == 'Ia'], 
             kde=True, label='Ia', bins=100, color=c[1])
sns.distplot(data['RandomSampling'][0]['prob_Ia'][data['RandomSampling'][0]['type'] != 'Ia'], 
             kde=True, label='nonIa', bins=100, color=c[0])
plt.legend(title='Initial state')
plt.xlabel('prob_Ia',fontsize=18)
plt.ylabel('PDF', fontsize=18)
plt.axvline(0.5, ls='--')

#plt.show()
plt.savefig('../../../../referee/plots/prob_evolution_loop0.pdf')
# Out:
# /media/emille/git/Fink/supernova_al/venv/fink-al-sn/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /media/emille/git/Fink/supernova_al/venv/fink-al-sn/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(16, 5))

plt.subplot(1,2,1)
sns.distplot(data['RandomSampling'][299]['prob_Ia'][data['RandomSampling'][299]['type'] == 'Ia'], 
             kde=True, label='Ia -- loop 300', bins=100, color=c[1])
sns.distplot(data['RandomSampling'][299]['prob_Ia'][data['RandomSampling'][299]['type'] != 'Ia'], 
             kde=True, label='nonIa -- loop 300', bins=100, color=c[0])
plt.legend(title='RandomSampling')
plt.xlabel('prob_Ia',fontsize=18)
plt.ylabel('PDF', fontsize=18)
plt.axvline(0.5, ls='--')

plt.subplot(1,2,2)
sns.distplot(data['UncSampling'][299]['prob_Ia'][data['UncSampling'][299]['type'] == 'Ia'], 
             kde=True, label='Ia -- loop 300', bins=100, color=c[1])
sns.distplot(data['UncSampling'][299]['prob_Ia'][data['UncSampling'][299]['type'] != 'Ia'], 
             kde=True, label='nonIa -- loop 300', bins=100, color=c[0])
plt.legend(title='UncSampling')
plt.xlabel('prob_Ia',fontsize=18)
plt.ylabel('PDF', fontsize=18)
plt.axvline(0.5, ls='--')

plt.subplots_adjust(hspace=0.3)
#plt.show()
plt.savefig('../../../../referee/plots/prob_evolution_loop299.pdf')
# Out:
# /media/emille/git/Fink/supernova_al/venv/fink-al-sn/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /media/emille/git/Fink/supernova_al/venv/fink-al-sn/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
